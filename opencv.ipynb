# %%
# coding = utf-8
import cv2
import os
import numpy as np
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 读写

# %%
im=cv2.imread("test.jpg")
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
plt.imshow(im)

# %%
img_gray = cv2.cvtColor(im,cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)

# %%
cv2.imwrite('gray.jpg',img_gray)

# %% [markdown]
# # fillConvexPoly 单体

# %%
img = np.zeros((1080, 1920, 3), np.uint8)
triangle = np.array([[0, 0], [1000, 800], [500, 200]])
 
cv2.fillConvexPoly(img, triangle, (255, 200, 255))

plt.imshow(img)
plt.show()

# %% [markdown]
# # fillPoly 多体

# %%
img = np.zeros((1080, 1920, 3), np.uint8)
area1 = np.array([[250, 200], [300, 100], [750, 800], [100, 1000]])
area2 = np.array([[1000, 200], [1500, 200], [1500, 400], [1000, 400]])
 
cv2.fillPoly(img, [area1, area2], (255, 255, 255),1)
 
plt.imshow(img)
plt.show()

# %% [markdown]
# # polylines

# %%
reg = np.array([[[419,411], [847,427], [825,663], [405,633]]], dtype = np.int32)
print(reg.shape)
#im = np.zeros([240, 320], dtpe = np.uint8)
cv2.polylines(im, reg,True, (100,200,255))
#cv2.fillPoly(im,reg,(0,255,255))
plt.imshow(im)
#plt.show()
# Out:
# (1, 4, 2)

# %% [markdown]
# # putText

# %%
img = np.zeros((512,512,3), np.uint8)

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'OpenCV',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)

cv2.imshow('show',img)
plt.imshow(img)
